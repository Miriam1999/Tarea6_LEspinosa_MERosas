# %% [markdown]
# <img style = "float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width = "300" height = "500" />
#
#
# ### <font color = 'navy'> Simulación de procesos financieros.
#
# **Nombres:** Lyha Espinosa García y Miriam Eunice Rosas Medellín.
#
# **Fecha:** 8 de marzo del 2021.
#
# **Expediente** : 721861 y 721278.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 6: Clase 10
# **Link al repositorio en Github**: https://github.com/Miriam1999/Tarea6_LEspinosa_MERosas

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Recordar que:
# $$X\sim binomial(n, p) \longrightarrow p_i = P(X = i) = \frac{n!}{i!(n - i)!}p^i(1 - p)^{n - i}, \quad i = 0,1,\cdots, n$$
# Demostrar la validez de la siguiente ecuación:
# >$$p_{i + 1} = \frac{n - i}{i+1} \frac{p}{1 - p} p_i \longrightarrow \text{Hablar de las ventajas de que sea recursiva}$$

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Markdown

# %% [markdown]
# 1. Se divide $\frac{p_{i+1}}{p_i}$, y obtenemos un cociente, que podemos lograr simplificar con la propiedad del factorial que establece que $\frac{n!}{(n+1)!} = \frac{1}{n+1}$.
# 2. Por lo tanto:  $\frac{p_{i+1}}{p_i} = \frac{n!p^ip(1-p)^ni!(n-i)!(1-p)^i}{(1-p)^i(1-p)(i+1)!(n-i+1)!n!p^i(1-p)^n}$
# 3. Al simplificar: $\frac{p_{i+1}}{p_i} =\frac{(n-i)p}{(i+1)(1-p)}$
# 4. Finlmente: $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# Es más sencillo utilizar esta ecuación en una función ya que de no ser así, el calculo de los factoriales vuelve un poco ineficiente el código ya que se requieren operaciones con más iteraciones.

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Markdown

# %% [markdown]
# **Demostración matemática**:
# 1. Para demostrar la ecuación recursiva, se puede dividir $\frac{p_{i + 1}}{p_i}$ (en $p_{i + 1}$ se sustituye $i = i + 1$):
# $$\frac{p_{i + 1}}{p_i} = \frac{\frac{n!}{(i + 1)!(n - (i + 1))!} p^{i + 1} (1 - p)^{n - (i + 1)}}{\frac{n!}{i! (n - i)!} p^i (1 - p)^{n - i}} = \frac{\frac{n! p^{i + 1} (1 - p)^{n - (i + 1)}}{(i + 1)!(n - (i + 1))!}}{\frac{n! p^i (1 - p)^{n - i}}{i! (n - i)!}} = \frac{n! p^{i + 1} (1 - p)^{n - (i + 1)} i! (n - i)!}{(i + 1)!(n - (i + 1))! n! p^i (1 - p)^{n - i}} = \frac{p^{i + 1} (1 - p)^{n - i - 1} i! (n - i)!}{(i + 1)! (n - i - 1)! p^i (1 - p)^{n - i}}$$
#
#
# 2. Pasando los exponentes del denominador hacia el numerador (se pasan con el signo contrario), se obtiene que:
# $$\frac{p^{i + 1 - i} (1 - p)^{n - i - 1 - n + i} i! (n - i)!}{(i + 1)! (n - i - 1)!} = \frac{p^{1} (1 - p)^{- 1} i! (n - i)!}{(i + 1)! (n - i - 1)!} = \frac{p \cdot i! (n - i)!}{(i + 1)! (n - i - 1)! (1 - p)}$$
#
#
# 3. Usando una propiedad de los factoriales, la cual dice que $\frac{i!}{(i + 1)!} = \frac{1}{i + 1}$, se obtiene que:
# $$\frac{p \cdot i! (n - i)!}{(i + 1)! (n - i - 1)! (1 - p)} = \frac{p \cdot 1 (n - i)!}{(i + 1) (n - i - 1)! (1 - p)} = \frac{p (n - i)!}{(i + 1) (n - i - 1)! (1 - p)}$$
#
#
# 4. Usando otra propiedad de los factoriales, la cual dice que $\frac{n!}{(n - 1)!} = n$ (para este caso, $n = n - i$, por lo tanto, la propiedad que aplica en realidad es $\frac{(n - i)!}{(n - i - 1)!} = n - i$), se obtiene que:
# $$\frac{p (n - i)!}{(i + 1) (n - i - 1)! (1 - p)} = \frac{p (n - i)}{(i + 1) (1 - p)}$$
#
#
# 5. Finalmente, despejando $p_{i + 1}$ se obtiene que:
# $$\frac{p_{i + 1}}{p_i} = \frac{p (n - i)}{(i + 1) (1 - p)}$$
# $$p_{i + 1} = \frac{p (n - i) p_i}{(i + 1) (1 - p)}$$
#
# Lo cual, en efecto, **desmuestra la validez de la ecuación recursiva** definida a partir de la fórmula para sacar probabilidades de una distribución binomial. Es más útil usar esta ecuación debido a que uno se ahorra el cálculo de los factoriales, pues se sabe que el factorial es una función que requiere de múltiples operaciones iterativas y por lo tanto su costo computacional es mucho mayor.

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# >$$P(k, \lambda) = \frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
# > Demuestre matemáticamente que
# > $$P(k + 1) = \frac{\lambda}{k + 1}P(k)$$
# > y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.
#
# Enlace: https://es.wikipedia.org/wiki/Distribuci%C3%B3n_de_Poisson

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Markdown

# %% [markdown]
# **Demostración**
# Se toma en cuenta la propiedad: $\frac{k!}{(k+1)!} = \frac{1}{k+1}$ por lo tanto:
# $$\frac{P(k+1)}{P(k)} = \frac{e^{-\lambda}\lambda^k\lambda k!}{(k+1)!e^{-\lambda}\lambda^k} = \frac{\lambda k!}{(k+1)!} = \frac{\lambda}{1+k}$$
#
#
# $$P(k+1) = \frac{\lambda}{k+1}P(k)$$

# %% [markdown]
# **Procedimiento**
# - Mediante la fórmula obtenida:
# $$P(k+1) = \frac{\lambda}{k+1}P(k)$$
# se genera una función para calcular la probabilidad acumulada
# - Se genera una distribución en base a esa probabilidad acumulada, y en base a valores reales aleatorios.
# - Para concluir se grafica el histograma de esta distribución de Poisson y se compara con la distribución de Poisson generada con `numpy.random.poisson()`

# %% [markdown]
# #### Código

# %%
import numpy as np
from scipy import optimize
import pandas as pd
import matplotlib.pyplot as plt

def Gen_distr_discreta(p_acum: 'P.Acumulada de la distribución a generar',
                       indices: 'valores reales a generar aleatoriamente',
                       N: 'cantidad de números aleatorios a generar'):
    
    U =np.random.rand(N)
    # Diccionario de valores aleatorios
    rand2reales = {i: idx for i, idx in enumerate(indices)}

    # Series de los valores aletorios
    y = pd.Series([sum([1 for p in p_acum if p < ui]) for ui in U]).map(rand2reales)

    return y

def plot_histogram_discrete(distribucion:'señal de varibles aleatorias de un distribución DISCRETA dada',
                            label:'label del legend a aparecer en el gráfica',
                            densidad:'por defecto regresa el histograma en densidad'=True):
    
    plt.figure(figsize=[10,4])
    y, x = np.histogram(distribucion, bins=len(set(distribucion)), density=densidad) 
    plt.bar(x[1:], y, label=label)

    plt.legend()
    plt.show()

# %%
np.random.seed(123) #semilla

def poisson_acum(l: 'valor de lambda', k: 'número de términos'):
    '''
    Función que calcula la probabilidad acumulada
    '''
    poisson = np.zeros(k) # vector de k ceros
    poisson[0] = (np.exp(-l)) # primer elemento del vector
    
    def vector(i):
        nonlocal poisson
        poisson[i+1] = (l*poisson[i])/(i + 1)
        
    [vector(i) for i in range(k-1)] # Llenar vector 
    return poisson.cumsum()  #retornar la suma acumulada

N, l, k = 10000, 5, 1000 # parametros 
p_acum = poisson_acum(l,k)

# Usando el método de la transformada inversa
d_poisson = Gen_distr_discreta(p_acum,np.arange(0, k+1), N)
plot_histogram_discrete(d_poisson,'usando función creada')

# Usando numpy
d_poisson_n = np.random.poisson(l,k)
plot_histogram_discrete(d_poisson_n,'usando numpy')

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Markdown

# %% [markdown]
# **Demostración matemática**:
# 1. Similar al ejercicio anterior, se puede demostrar la validez de la ecuación dividiendo $\frac{P(k + 1)}{P(k)}$ (en $P(k + 1)$ se sustituye $k = k + 1$):
# $$\frac{P(k + 1)}{P(k)} = \frac{\frac{e^{-\lambda}(\lambda)^{k + 1}}{(k + 1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}} = \frac{e^{-\lambda}(\lambda)^{k + 1} k!}{(k + 1)! e^{-\lambda}(\lambda)^k} = \frac{(\lambda)^{k + 1} k!}{(k + 1)! (\lambda)^k}$$
#
#
# 2. Pasando los exponentes del denominador hacia el numerador (se pasan con el signo contrario), se obtiene que:
# $$\frac{(\lambda)^{k + 1} k!}{(k + 1)! (\lambda)^k} = \frac{(\lambda)^{k + 1 - k} k!}{(k + 1)!} = \frac{(\lambda)^{1} k!}{(k + 1)!} = \frac{\lambda k!}{(k + 1)!}$$
#
#
# 3. Usando de nuevo la propiedad utilizada en el paso 3 del ejercicio anterior ($\frac{k!}{(k + 1)!} = \frac{1}{k + 1}$), se obtiene que:
# $$\frac{\lambda k!}{(k + 1)!} = \frac{\lambda \cdot 1}{k + 1} = \frac{\lambda}{k + 1}$$
#
#
# 4. Finalmente, despejando $P(k + 1)$ se obtiene que:
# $$\frac{P(k + 1)}{P(k)} = \frac{\lambda}{k + 1}$$
# $$P(k + 1) = \frac{\lambda P(k)}{k + 1}$$
#
# Lo cual, en efecto también demuestra la validez de la ecuación dada, obtenida a partir de la función de distribución de probabilidad de Poisson.

# %% [markdown]
# **El siguiente código se genera usando la lógica que sigue**:
# 1. Para llenar el primer elemento de la distribución (el vector de las probabilidades), es necesario sustituir $k = 0$ en la fórmula de $P(k, \lambda)$:
# $$\frac{e^{-\lambda}(\lambda)^k}{k!} = \frac{e^{-\lambda}(\lambda)^0}{0!} = \frac{e^{-\lambda} \cdot 1}{1} = e^{-\lambda}$$
#
# 2. Para llenar los demás elementos, basta con seguir la fórmula ya dada:
# $$P(k + 1) = \frac{\lambda}{k + 1}P(k)$$
#
# 3. Después se genera la distribución aleatoria en base a esas probabilidades, calculando la frecuencia absoluta de cada una de las $x$.
#
# 4. Finalmente se comparan dos histogramas: uno usando la distribución de Poisson generada en el procedimiento previo, y otro usando una distribución de Poisson generada con `numpy.random.poisson()`.

# %% [markdown]
# #### Código

# %%
import numpy as np
from scipy import optimize
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
np.random.seed(123) # semilla
def prob_acum_dist_poisson(l: "término lambda", k: "número de términos k"):
    """Esta función regresa un vector de la probabilidad acumulada 'P(x)' con base en los valores lambda 'l' y la constante 'k' 
    de la distribución de Poisson"""
    probabilidades = np.zeros(k) # vector de ceros tamaño k
    probabilidades[0] = np.exp(-l) # llenar el primer elemento
    def llenar_vector(i):
        nonlocal probabilidades
        probabilidades[i + 1] = (l * probabilidades[i]) / (i + 1)
    [llenar_vector(i) for i in range(k - 1)] # llenar los demás elementos
    return np.cumsum(probabilidades)
def generar_dist_discreta(p_acum: "vector de la probabilidad acumulada de la distribución a generar", 
                          k: "cantidad de números aleatorios a generar"):
    """Esta función regresa el vector con la frecuencia de cada uno de los números aleatorios generados"""
    x = np.random.rand(k) # generar N valores aleatorios uniformemente distribuidos entre 0 y 1
    y = pd.Series([sum([1 for p in p_acum if p < xi]) for xi in x]) # calcular la frecuencia de dichos de valores
    return y
def graficar_hist_discreto(distribucion: "distribución a graficar el histograma", title: "título del histograma"):
    """Esta función plotea el histograma de una variable discreta dada una distribución (un vector con la frecuencia de cada
    uno de los valores aleatorios generados), y un título de la gráfica"""
    plt.figure(figsize = (15, 7))
    y, x = np.histogram(distribucion, bins = len(set(distribucion)), density = True) 
    plt.bar(list(set(distribucion)), y, color = "y")
    plt.xlabel("Valores aleatorios", fontsize = 12)
    plt.ylabel("Frecuencia relativa (probabilidad)", fontsize = 12)
    plt.title(title, fontsize = 20)
    plt.grid(color = "#95a5a6", linestyle = '--', linewidth = 1.5, axis = "y", alpha = 0.7)
    plt.show()
k, l = 10000, 5 # número de muestras y lambda 'l'
p_acum = prob_acum_dist_poisson(l, k) # calcular la probabilidad acumulada con los lamnda 'l' y 'k' dados

# Usando el método de la transformada inversa
d_poisson_transformada = generar_dist_discreta(p_acum, k)
graficar_hist_discreto(d_poisson_transformada, "Histograma de distribución de Poisson con el método de la transformada inversa")

# Usando numpy
d_poisson_np = np.random.poisson(l, k)
graficar_hist_discreto(d_poisson_np, "Histograma de la distribución de Poisson usando NumPy")

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# Partiendo desde que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x) = 30 (x^2 - 2x^3 + x^4)$$
# Responda los siguientes literales:
# 1. Usar como función que mayora $f(x)$ a $t(x) = a \sin (\pi x)$ donde $a$ es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Código

# %%
# Función objetivo 
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp=False))

# Función t -> Función constante
t = lambda x: max_f * np.sin(np.pi*x)

# Rango donde se graficará las funciones
x = np.arange(0, 1, 0.01)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)',color='magenta')
plt.legend()

# %% [markdown]
# #### Markdown

# %% [markdown]
# Se verifica que se cumple la condición $t(x)\geq f(x)$.

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Código

# %%
np.random.seed(123) # semilla
def comparacion_grafica(f: "función de densidad f(x)", t: "función para validar t(x)", N: "número de muestras"):
    """Función que plotea la función de densidad 'f(x)' y la función para validar 't(x)' con el objetivo de compararlas"""
    x = np.arange(0, 1, 1 / N) # vector de N xs
    plt.figure(figsize = (15, 7))
    plt.plot(x, f(x), label = "Función de densidad f(x)")
    plt.plot(x, t(x), label = "Función de validación t(x)")
    plt.xlabel("x", fontsize = 12)
    plt.ylabel("Probabilidad", fontsize = 12)
    plt.title("Comparación entre la función de densidad f(x) y la función de validación t(x)", fontsize = 20)
    plt.grid(color = "#95a5a6", linestyle = '--', linewidth = 1.5, axis = "y", alpha = 0.7)
    plt.legend()
    plt.show() 
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4) # función de densidad f(x)
max_f = f(optimize.fmin(lambda x: -f(x), 0, disp = False)) # máximo de la función f(x)
t = lambda x: max_f * np.sin(np.pi * x) # función de validación t(x)
N = 1000 # número de muestras
comparacion_grafica(f, t, N) # comparación entre la función de densidad y la de validación

# %% [markdown]
# #### Markdown

# %% [markdown]
# Con esta gráfica, se comprueba que la función de validación $t(x)$ es mayor que la función de densidad $f(x)$ en todo el dominio excepto en x = 0.5, donde ambas tienen la misma probabilidad.

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Markdown

# %% [markdown]
# 1. Obtener el valor de c: $$c = \int_{0}^{1}t(x)dx = \int_{0}^{1} asin(\pi x) dx = \frac{-a}{\pi}[cos(\pi x)]_{0}^{1} = \frac{2a}{\pi}$$
#
# 2. Sustituir C para obtener $g(x)$: $$g(x) = \frac{t(x)}{c} = \frac{\frac{asin(\pi x)}{1}}{\frac{2a}{\pi}} = \frac{\pi sin(\pi x)}{2} $$

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Markdown

# %% [markdown]
# **Pasos a seguir para obtener la función de densidad $g(x)$**:
# 1. Obtener c con el método de sustitución $u = \pi x$ y $du = \pi dx$, o sea que $dx = \frac{du}{\pi}$:
#
# $$c = \int_{0}^{1} t(x) = \int_{0}^{1} a \sin(\pi x) dx = a \int_{0}^{1} \sin(u) \frac{du}{\pi} = \frac{a}{\pi} \int_{0}^{1} \sin(u) du = \frac{a}{\pi} [-\cos(u)]_{0}^{1} = \frac{a}{\pi} [-\cos(\pi x)]_{0}^{1} = \frac{a}{\pi} [-\cos(1 \cdot \pi) + \cos(0 \cdot \pi)] = \frac{a}{\pi} [-\cos(\pi) + \cos(0)] = \frac{a}{\pi} [-(-1) + 1]= -\frac{a}{\pi} (1 + 1) = \frac{2a}{\pi}$$
#
# 2. Obtener $g(x)$ = $\frac{t(x)}{c}$:
# $$g(x) = \frac{a \sin(\pi x)}{\frac{2a}{\pi}} = \frac{\frac{a \sin(\pi x)}{1}}{\frac{2a}{\pi}} = \frac{\pi a \sin(\pi x)}{2 a} = \frac{\pi \sin(\pi x)}{2}$$

# %% [markdown]
# ## Ejercicio 5

# %% [markdown]
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente y similar al punto anterior, reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Markdown

# %% [markdown]
# 1. Integramos $g(x)$ para obtener $G(x)$:
# $$G(x) = \int_{0}^{x}g(x) = \int_{0}^{x}\frac{\pi}{2}sin(\pi x) = -\frac{1}{2}[cos(\pi x)]_{0}^{x}$$
# $$ G(x) = -\frac{1}{2}cos(\pi x) + \frac{1}{2}$$
#
# 2. Método de la transformada inversa:
# $$ G(x) = -\frac{1}{2}cos(\pi x) + \frac{1}{2}$$
# $$ U = -\frac{1}{2}cos(\pi x) + \frac{1}{2}$$
# $$ -2U + 1 = cos(\pi x) $$
# $$ x = \frac{cos^{-1}(-2U +1)}{\pi}$$

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Markdown

# %% [markdown]
# **Pasos a seguir para obtener la transformada inversa**:
# 1. Obtener funcion de distribución acumulada $G(x)$ con el método de sustitución $u = \pi x$ y $du = \pi dx$, o sea que $dx = \frac{du}{\pi}$:
# $$G(x) = \int_{0}^{x}g(x) = \int_{0}^{x} \frac{\pi}{2} \sin(\pi x) dx = \frac{\pi}{2} \int_{0}^{x} \sin(u) \frac{du}{\pi} = \frac{\pi}{2} \cdot \frac{1}{\pi} \int_{0}^{x} \sin(u) du = \frac{1}{2} \int_{0}^{x} \sin(u) du = \frac{1}{2} [-\cos(u)]_{0}^{x} = \frac{1}{2} [-\cos(\pi x)]_{0}^{x} = \frac{1}{2} [-\cos(x \pi) + \cos(0 \cdot \pi)] = \frac{1}{2} [-\cos(x \pi) + \cos(0)] = \frac{1}{2} [-\cos(x \pi) + 1]= -\frac{1}{2} \cos(x \pi) + \frac{1}{2}$$
#
#
# 2. Obtener función inversa asumiendo que $G(x)$ es uniforme continua:
# $$ G(x) = -\frac{1}{2} \cos(x \pi) + \frac{1}{2} = \frac{- \cos(x \pi) + 1}{2} = U$$
# $$ 2U = - \cos(x \pi) + 1 $$
# $$ \cos(x \pi) = -2U + 1 $$
# $$ x \pi = \cos^{-1}(1 - 2U) $$
# $$ x = \frac{\cos^{-1}(1 - 2U)}{\pi}$$

# %% [markdown]
# ## Ejercicio 6

# %% [markdown]
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Código

# %%
g = lambda x: (np.pi/2)*(np.sin(np.pi*x)) # densidad
G_inv = lambda u: ((np.arccos(2*(1/2-u)))/np.pi) # transformada inversa
N = 10000 # numero de muestras

def comparacion_gx_gin(g: 'Funcion de densidad g(x) ', G_inv: 'Transfromada Inversa de G(x)' , N: 'Numero de va a generar' ):
    '''
    Funcion para comparar una funcion g(x) con el histograma de una funcion inversa
    '''
    u = np.random.rand(N) # valores aleatorios distribuidos en U 
    g_random = G_inv(u)   # evaluar la transformada inversa en esos valores
    x = np.arange(0,1,0.01) # valores aleatorios para x
    density_g = g(x)        # evaluar funcion de densidad en esos valores
    
    plt.hist(g_random, bins = 50, density = True, color='c') 
    plt.plot(x, density_g, color = 'magenta')
    
    plt.xlabel("Valores aleatorios")
    plt.ylabel("Probabilidad")
    plt.title("Transformada inversa")
    
    plt.show();


comparacion_gx_gin(g,G_inv,N)

# %% [markdown]
# #### Markdown

# %% [markdown]
# El histograma de la transformada inversa $G(x)$ coincide con la función de densidad $g(x)$

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Código

# %%
np.random.seed(123) # semilla
def comparacion_ginv_x(g: "función de densidad 'g(x)''", G_inv: "transformada inversa de la función de distribución 'G(x)'", 
                       N: "número de muestras"):
    """Esta función compara la función de densidad (probabilidad) evaluada en x 'g(x)'con la transformada inversa de la función 
    de distribución (probabilidad acumulada) evaluada en números aleatorios uniforme y continuamente distribuidos"""
    u = np.random.rand(N) # generar las muestras aleatorias, continuas e uniformemente distribuidas U
    g_random = G_inv(u) # evaluar la transformada en los valores aleatorios
    x = np.arange(0, 1, (1 / N)) # generar N valores en x
    g_densidad = g(x) # evaluar la función de densidad en los valores de x g(x)
    plt.figure(figsize = (15, 7)) # histograma
    plt.plot(x, g_densidad)
    plt.hist(g_random, bins = 100, density = True)
    plt.xlabel("Valores aleatorios", fontsize = 12)
    plt.ylabel("Frecuencia relativa (probabilidad)", fontsize = 12)
    plt.title("Histograma con el método de la transformada inversa 'G_inv(U)'", fontsize = 20)
    plt.grid(color = "#95a5a6", linestyle='--', linewidth = 1.5, axis = "y", alpha = 0.7)
    plt.show()
g = lambda x: (np.pi / 2) * (np.sin(np.pi * x)) # función de densidad g(x)
G_inv = lambda u: ((np.arccos(1 - 2 * u)) / np.pi) # transformada inversa de la función de probabilidad acumulada
N = 10000 # número de muestras
comparacion_ginv_x(g, G_inv, N) # comparar histograma de la transformada inversa y la función de densidad

# %% [markdown]
# #### Markdown

# %% [markdown]
# En efecto, la transformada inversa de $G(x)$ evaluada en $10,000$ valores aleatoria e uniformemente distribuidos siguen la distribución deseada, pues coinciden con la gráfica de la función de densidad $g(x)$.

# %% [markdown]
# ## Ejercicio 7

# %% [markdown]
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Código

# %%
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):

    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]            
    
    plt.xlabel("Valores aleatorios")
    plt.ylabel("Probabilidad")
    plt.title("Método de aceptación y rechazo")
    
    plt.show()
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    return x

# %%
# Función objetivo 
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
# Función t -> Función pulso senoidal 
t = lambda x: max_f * np.sin(np.pi*x)

# Rango donde se graficará las funciones
x = np.arange(0, 1, 1/N)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 500 # número de puntos a simular

R2 = np.random.rand(N)  # valores aleatorios uniformes
R1 = np.random.uniform(0, 1, size=N) # valores aleatorios uniformes


# Prueba de función creada
x_r = Acep_rechazo(R1, R2, f, t)

# %% [markdown]
# #### Markdown

# %% [markdown]
# La gráfica muestra que los puntos dentro de la función de densidad (puntos azules) son aceptados, y los demas puntos que se encuentran entre la $t(x)$ y $f(x)$ son los rechazados.

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Código

# %%
np.random.seed(123) # semilla
def grafica_acep_rechazo(R2: "variables distribuidas U ~ U(0, 1)'", R1: "variables distribuidas como g(x)", 
                         f: "función objetivo a generar", t: "función que mayora a f(x)", N: "número de muestras"):
    """Esta función ilustra de manera gráfica el método de aceptación y rechazo, recibiendo como parámetros 'R2', 'R1', 'f'y 
    't'"""
    fx = f(R1) 
    tx = t(R1)
    condition = R2 * tx <= fx  # si se cumple la condición, los valores son aceptados
    x = np.arange(0, 1, 1 / N) # generar N xs
    plt.figure(figsize = (15, 7))
    plt.plot(x, f(x), label = "f(x)") # plotear f(x)
    plt.plot(x, t(x), label = "t(x)") # plotear t(x) 
    [plt.plot(R1[i], R2[i] * tx[i], "oc") if condition[i] else plt.plot(R1[i], R2[i] * tx[i], "om") for i in range(len(R1))]
    plt.xlabel("Valores aleatorios", fontsize = 12)
    plt.ylabel("Frecuencia relativa (probabilidad)", fontsize = 12)
    plt.title("Valores aceptados y rechazados con el método de aceptación y rechazo", fontsize = 20)
    plt.grid(color = "#95a5a6", linestyle = '--', linewidth = 1.5, axis = "y", alpha = 0.7)
    plt.legend()
    plt.show()
N = 500 # número de muestras
f = lambda x: 30*(x**2 - 2 * x**3 + x**4) # función de densidad f(x)
max_f = f(optimize.fmin(lambda x: -f(x), 0, disp = False)) # parámetro 'a'
t = lambda x: max_f * np.sin(np.pi * x) # función de validación t(x)
R2 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
R1 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
grafica_acep_rechazo(R2, R1, f, t, N) # plotear la gráfica de los puntos aceptados y rechazados

# %% [markdown]
# #### Markdown

# %% [markdown]
# Esta gráfica demuestra que los cálculos anteriores están perfectamenre realizados, pues los puntos color morado en efecto están dentro de la función de densidad (son aceptados) y los puntos de los otros colores no (son rechazados porque no están por debajo de la función de densidad $f(x)$, pero sí por debajo de la función de validación $t(x)$).

# %% [markdown]
# ## Ejercicio 8

# %% [markdown]
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal y concluir.

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Código

# %%
N = 500 # número de puntos a simular
# Función objetivo 
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
# Función t -> Función Constante
t = lambda x: max_f * np.ones([len(x)])

# Rango donde se graficará las funciones
x = np.arange(0, 1, 1/N)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()


# Como estoy tomando t(x) constante solo es necesario generar valores aleatorios U~(0,1)
R2 = np.random.rand(N) 
R1 = np.random.uniform(0, 1, size=N)


# Prueba de función creada
x_r2 = Acep_rechazo(R1, R2, f, t)

# %%
#Función constante
prob_c = len(x_r2)/500
#Pulso senoidal 
prob_ps = len(x_r)/500

prob_c, prob_ps
# Out:
# (0.488, 0.73)

# %% [markdown]
# #### Markdown

# %% [markdown]
# - El porcentaje de aceptación cuando se usa $t(x)$ constante es de $53.8\%$
# - El porcentaje de aceptación cuando $t(x)$ es un pulso senoidal es de $70.6\%$

# %% [markdown]
# Mientras más similares son las funciones $t(x)$ y $f(x)$ el porcentaje de aceptación es mayor

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Código

# %%
np.random.seed(123) # semilla
def var_acep_rechazo(R2: "variables distribuidas U ~ U(0, 1)'", R1: "variables distribuidas como g(x)", 
                     f: "función objetivo a generar", t: "función que mayora a f(x)"):
    """Esta función, en lugar de graficar el método de aceptación y rechazo, sirve para generar valores aleatorios que sean
    aceptados."""
    fx = f(R1)
    tx = t(R1)
    condition = R2 * tx <= fx # si se cumple la condición, los valores son aceptados
    return [R1[i] for i in range(len(R1)) if condition[i]] # se agregan a esta lista los valores que son aceptados
N = 500 # número de muestras
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4) # f(x)
max_f = f(optimize.fmin(lambda x: -f(x), 0, disp = False)) # parámetro 'a'
t_cte = lambda x: max_f * np.ones(len(x)) # t constante
t_sin = lambda x: max_f * np.sin(np.pi * x) # t senoidal
R2 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
R1 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
grafica_acep_rechazo(R2, R1, f, t_cte, N) # primero ploteo la gráfica
print("El " + str((len(var_acep_rechazo(R2, R1, f, t_cte)) / N) * 100) + "% de los valores son aceptados con la t(x) constante."
     )
print("El " + str((len(var_acep_rechazo(R2, R1, f, t_sin)) / N) * 100) + "% de los valores son aceptados con la t(x) sinoidal.")
# Out:
# El 56.8% de los valores son aceptados con la t(x) constante.
# El 72.8% de los valores son aceptados con la t(x) sinoidal.

# %% [markdown]
# #### Markdown

# %% [markdown]
# Mientras más cercano sea el rango de la función de validación $t(x)$ al de la función de densidad $f(x)$, más porcentaje de valores serán aceptados dentro de la metodología de aceptación y rechazo. Sin embargo, puede resultar más fácil definir una función $t(x)$ constante, pues para crearla sólo es necesario obtener el valor máximo de la función de densidad; es decir, $t(x) = max(f)$.

# %% [markdown]
# ## Ejercicio 9

# %% [markdown]
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF $$f(x) = 20x (1 - x)^3$$ usando el método de aceptación y rechazo.

# %% [markdown]
# ### Solución de Lyha

# %% [markdown]
# #### Código

# %%
def Acep_rechazo_2(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
#     [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
#          for i in range(len(R1))] 
#     plt.show()
    
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    
    return x

# %%
N = 100 # número de puntos a simular
# Función objetivo 
f = lambda x: 20*x * (1 - x)**3
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
# Función t -> Función constante
t = lambda x: max_f * np.ones([len(x)])

# Rango donde se graficará las funciones
x = np.arange(0, 1, 1/N)
print('El máximo de f es:',max_f)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()


# Validación del método
N = 20000 # número de puntos a simular

# Como estoy tomando t(x) constante solo es necesario generar valores aleatorios U~(0,1)
R2 = np.random.rand(N) 
R1 = np.random.uniform(0, 1, size=N)

x_r = Acep_rechazo_2(R1, R2, f, t) #Método de acetación y rechazo

y,x_n, _ = plt.hist(x_r, bins=50, density=True)
# Out:
# El máximo de f es: [2.109375]

# %% [markdown]
# ### Solución de Miriam

# %% [markdown]
# #### Código

# %%
np.random.seed(123) # semilla
f = lambda x: 20 * x * (1-  x)**3 # nueva f(x)
max_f = f(optimize.fmin(lambda x: -f(x), 0, disp = False)) # máximo de la función f(x)
t_cte = lambda x: max_f * np.ones(len(x)) # en esta ocasión la t(x) es constante
N = 500 # número de muestras
R2 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
R1 = np.random.rand(N) # valores aleatorios uniformemente distribuidos
grafica_acep_rechazo(R2, R1, f, t_cte, N) # plotear la gráfica de los puntos aceptados y rechazados
print("Una muestra de 10 valores aleatorios de la variable X es la siguiente: \n", var_acep_rechazo(R2, R1, f, t_cte)[:10])
# Out:
# Una muestra de 10 valores aleatorios de la variable X es la siguiente:
#  [0.21283149856914907, 0.3923040710839275, 0.12761222421802076, 0.4965079723751131, 0.3056463880931184, 0.5176234607612891, 0.3033807340330762, 0.33981085404434463, 0.44132413545947113, 0.3975640516334864]

# %%
x_grid = np.arange(0, 1, 100)
plt.figure(figsize = [15, 7])
plt.plot(x, f(x), color = "r", label = "$f(x) = 20x (1 - x)^3$")
plt.title("Histograma de las variables aleatorias generadas en el método de aceptación y rechazo", fontsize = 20)
plt.xlabel("Valores aleatorios", fontsize = 12)
plt.ylabel("Frecuencia relativa (probabilidad)", fontsize = 12)
y,x_n, _ = plt.hist(var_acep_rechazo(R2, R1, f, t_cte), bins = 10, density = True, color = "black")
plt.legend()
plt.show()

# %% [markdown]
# #### Markdown

# %% [markdown]
# Tras generar una variable aleatoria con función de densidad $f(x) = 20x (1 - x)^3$ y una función de validación $t(x)$ constante, se obtuvo la anterior gráfica de los valores aceptados (azul) y rechazados (morado) del método de aceptación y rechazo. Adicionalmente, se imprime una muestra de $10$ valores de la variable aleatoria $X$ generada.
